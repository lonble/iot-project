# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from pandas>=1.2->seaborn) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\miniconda3\envs\iot_ml\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import seaborn as sns

# %%
df = pd.read_csv("all_samples.csv")

print("Dataset shape:", df.shape)

df.head()
# Out:
# Dataset shape: (835971, 9)
#   environment  test    sensor  sample_index                timestamp  \
# 0      bridge     1  sensor_1             1  2026-03-05 16:36:37,951
# 1      bridge     1  sensor_1             2  2026-03-05 16:36:37,956
# 2      bridge     1  sensor_1             3  2026-03-05 16:36:37,976
# 3      bridge     1  sensor_1             4  2026-03-05 16:36:37,990
# 4      bridge     1  sensor_1             5  2026-03-05 16:36:37,999
#
#                         addr  rssi  lqi   source_file
# 0  fe80::e41d:23d2:4964:c6f9   -88   20  Bridge 1.log
# 1  fe80::e41d:23d2:4964:c6f9   -87   24  Bridge 1.log
# 2  fe80::e41d:23d2:4964:c6f9   -88   20  Bridge 1.log
# 3  fe80::e41d:23d2:4964:c6f9   -88   20  Bridge 1.log
# 4  fe80::e41d:23d2:4964:c6f9   -88   20  Bridge 1.log

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835971 entries, 0 to 835970
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   environment   835971 non-null  object
#  1   test          835971 non-null  int64
#  2   sensor        835971 non-null  object
#  3   sample_index  835971 non-null  int64
#  4   timestamp     835971 non-null  object
#  5   addr          835971 non-null  object
#  6   rssi          835971 non-null  int64
#  7   lqi           835971 non-null  int64
#  8   source_file   835971 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 57.4+ MB

# %%
df['environment'].value_counts()
# Out:
# environment
# bridge    222785
# forest    200268
# lake      169994
# river     138044
# garden    104880
# Name: count, dtype: int64

# %%
df['sensor'].value_counts()
# Out:
# sensor
# sensor_1    450149
# sensor_2    385822
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
plt.hist(df['rssi'], bins=50)
plt.title("RSSI Distribution")
plt.xlabel("RSSI")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="environment", y="rssi", data=df)

plt.title("RSSI Distribution per Environment")

plt.show()

# %%
df.to_csv("clean_data.csv", index=False)

print("Saved clean_data.csv")
# Out:
# Saved clean_data.csv
